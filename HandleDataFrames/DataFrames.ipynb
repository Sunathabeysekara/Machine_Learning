# %%
import pandas as pd
import numpy as np

data_file=r'C:\Users\SUNATH\Desktop\four1 practicle\ML\p1\CAR DETAILS FROM CAR DEKHO.csv'
dataset=pd.read_csv(data_file)

# %%
dataset
# Out:
#                                      name  year  selling_price  km_driven  \
# 0                           Maruti 800 AC  2007          60000      70000
# 1                Maruti Wagon R LXI Minor  2007         135000      50000
# 2                    Hyundai Verna 1.6 SX  2012         600000     100000
# 3                  Datsun RediGO T Option  2017         250000      46000
# 4                   Honda Amaze VX i-DTEC  2014         450000     141000
# ...                                   ...   ...            ...        ...
# 4335  Hyundai i20 Magna 1.4 CRDi (Diesel)  2014         409999      80000
# 4336           Hyundai i20 Magna 1.4 CRDi  2014         409999      80000
# 4337                  Maruti 800 AC BSIII  2009         110000      83000
# 4338     Hyundai Creta 1.6 CRDi SX Option  2016         865000      90000
# 4339                     Renault KWID RXT  2016         225000      40000
#
#         fuel seller_type transmission         owner
# ...

# %%
dataset.head(5)
# Out:
#                        name  year  selling_price  km_driven    fuel  \
# 0             Maruti 800 AC  2007          60000      70000  Petrol
# 1  Maruti Wagon R LXI Minor  2007         135000      50000  Petrol
# 2      Hyundai Verna 1.6 SX  2012         600000     100000  Diesel
# 3    Datsun RediGO T Option  2017         250000      46000  Petrol
# 4     Honda Amaze VX i-DTEC  2014         450000     141000  Diesel
#
#   seller_type transmission         owner
# 0  Individual       Manual   First Owner
# 1  Individual       Manual   First Owner
# 2  Individual       Manual   First Owner
# 3  Individual       Manual   First Owner
# 4  Individual       Manual  Second Owner

# %%
dataset.tail(5)
# Out:
#                                      name  year  selling_price  km_driven  \
# 4335  Hyundai i20 Magna 1.4 CRDi (Diesel)  2014         409999      80000
# 4336           Hyundai i20 Magna 1.4 CRDi  2014         409999      80000
# 4337                  Maruti 800 AC BSIII  2009         110000      83000
# 4338     Hyundai Creta 1.6 CRDi SX Option  2016         865000      90000
# 4339                     Renault KWID RXT  2016         225000      40000
#
#         fuel seller_type transmission         owner
# 4335  Diesel  Individual       Manual  Second Owner
# 4336  Diesel  Individual       Manual  Second Owner
# 4337  Petrol  Individual       Manual  Second Owner
# 4338  Diesel  Individual       Manual   First Owner
# 4339  Petrol  Individual       Manual   First Owner

# %%
dataset.columns
# Out:
# Index(['name', 'year', 'selling_price', 'km_driven', 'fuel', 'seller_type',
#        'transmission', 'owner'],
#       dtype='object')

# %%
dataset.drop(columns=['seller_type','transmission'])
# Out:
#                                      name  year  selling_price  km_driven  \
# 0                           Maruti 800 AC  2007          60000      70000
# 1                Maruti Wagon R LXI Minor  2007         135000      50000
# 2                    Hyundai Verna 1.6 SX  2012         600000     100000
# 3                  Datsun RediGO T Option  2017         250000      46000
# 4                   Honda Amaze VX i-DTEC  2014         450000     141000
# ...                                   ...   ...            ...        ...
# 4335  Hyundai i20 Magna 1.4 CRDi (Diesel)  2014         409999      80000
# 4336           Hyundai i20 Magna 1.4 CRDi  2014         409999      80000
# 4337                  Maruti 800 AC BSIII  2009         110000      83000
# 4338     Hyundai Creta 1.6 CRDi SX Option  2016         865000      90000
# 4339                     Renault KWID RXT  2016         225000      40000
#
#         fuel         owner
# 0     Petrol   First Owner
# ...

# %%
dataset.iloc[:4,:-1]
# Out:
#                        name  year  selling_price  km_driven    fuel  \
# 0             Maruti 800 AC  2007          60000      70000  Petrol
# 1  Maruti Wagon R LXI Minor  2007         135000      50000  Petrol
# 2      Hyundai Verna 1.6 SX  2012         600000     100000  Diesel
# 3    Datsun RediGO T Option  2017         250000      46000  Petrol
#
#   seller_type transmission
# 0  Individual       Manual
# 1  Individual       Manual
# 2  Individual       Manual
# 3  Individual       Manual

# %%
dataset[dataset.year>2010]
# Out:
#                                               name  year  selling_price  \
# 2                             Hyundai Verna 1.6 SX  2012         600000
# 3                           Datsun RediGO T Option  2017         250000
# 4                            Honda Amaze VX i-DTEC  2014         450000
# 6                        Hyundai Xcent 1.2 Kappa S  2016         550000
# 7                         Tata Indigo Grand Petrol  2014         240000
# ...                                            ...   ...            ...
# 4334  Toyota Innova 2.5 VX (Diesel) 8 Seater BS IV  2012         600000
# 4335           Hyundai i20 Magna 1.4 CRDi (Diesel)  2014         409999
# 4336                    Hyundai i20 Magna 1.4 CRDi  2014         409999
# 4338              Hyundai Creta 1.6 CRDi SX Option  2016         865000
# 4339                              Renault KWID RXT  2016         225000
#
#       km_driven    fuel seller_type transmission         owner
# ...

# %%
dataset.selling_price.values
# Out:
# array([ 60000, 135000, 600000, ..., 110000, 865000, 225000], dtype=int64)

# %%
#tabseperated format
#df=pd.read_csv('_.txt',delimiter='\t')

#excel
#df=pd.read_excel('_.xlsx')

# %%
#read headers
dataset.columns
# Out:
# Index(['name', 'year', 'selling_price', 'km_driven', 'fuel', 'seller_type',
#        'transmission', 'owner'],
#       dtype='object')

# %%
#read columns each
dataset['name'][0:5]
# Out:
# 0               Maruti 800 AC
# 1    Maruti Wagon R LXI Minor
# 2        Hyundai Verna 1.6 SX
# 3      Datsun RediGO T Option
# 4       Honda Amaze VX i-DTEC
# Name: name, dtype: object

# %%
dataset.name
# Out:
# 0                             Maruti 800 AC
# 1                  Maruti Wagon R LXI Minor
# 2                      Hyundai Verna 1.6 SX
# 3                    Datsun RediGO T Option
# 4                     Honda Amaze VX i-DTEC
#                        ...
# 4335    Hyundai i20 Magna 1.4 CRDi (Diesel)
# 4336             Hyundai i20 Magna 1.4 CRDi
# 4337                    Maruti 800 AC BSIII
# 4338       Hyundai Creta 1.6 CRDi SX Option
# 4339                       Renault KWID RXT
# Name: name, Length: 4340, dtype: object

# %%
dataset
# Out:
#                                      name  year  selling_price  km_driven  \
# 0                           Maruti 800 AC  2007          60000      70000
# 1                Maruti Wagon R LXI Minor  2007         135000      50000
# 2                    Hyundai Verna 1.6 SX  2012         600000     100000
# 3                  Datsun RediGO T Option  2017         250000      46000
# 4                   Honda Amaze VX i-DTEC  2014         450000     141000
# ...                                   ...   ...            ...        ...
# 4335  Hyundai i20 Magna 1.4 CRDi (Diesel)  2014         409999      80000
# 4336           Hyundai i20 Magna 1.4 CRDi  2014         409999      80000
# 4337                  Maruti 800 AC BSIII  2009         110000      83000
# 4338     Hyundai Creta 1.6 CRDi SX Option  2016         865000      90000
# 4339                     Renault KWID RXT  2016         225000      40000
#
#         fuel seller_type transmission         owner
# ...

# %%
###############################
#############################
###########################
import matplotlib.pyplot as plt

# %%
x=dataset.year
y=dataset.selling_price

plt.scatter(x,y,c='black',marker='x')

# %%
x=[18,2,23,5,6,3,23,3,12,31,23,12,3,12,1,3,21,23,12,30,86]
y=[1,12,32,4,53,6,7,8,21,42,72,56,54,54,3,4,2,22,67,4,3]
print(len(x))
print(len(y))
# Out:
# 21
# 21

# %%
#scattter plot
plt.scatter(x,y,s=190,c='red',alpha=.3)#x,y,size,color,overlap can be shown by alpha
plt.show()

# %%
#line plot

years=[2006 + x for x in range(20)]
weight=[67,56,98,56,75,86,80,57,58,59,65,63,68,70,85,59,65,86,97,56]

plt.plot(years,weight,c='green',lw=2,linestyle='--',)
plt.show()

# %%
x=['c++','c#','java','pyhton','go','c']
y=[45,34,65,34,45,43]
plt.bar(x,y,color='g',align='edge',width=0.2,edgecolor='r')
plt.show()

# %%
plt.hist(x,cumulative=True)
plt.show()

# %%
#piechar
explodes=[0.3,0,0,0,0,0]
plt.pie(y,labels=x,explode=explodes,autopct="%.3f",pctdistance=1.3,startangle=24)
plt.show()

# %%
#boxplot
x=np.random.normal(150,8,200)#mean,std-diviation,200 nums
plt.boxplot(x)
# Out:
# {'whiskers': [<matplotlib.lines.Line2D at 0x27dd8cf7f40>,
# ...
#  'caps': [<matplotlib.lines.Line2D at 0x27dd8d05520>,
# ...
#  'boxes': [<matplotlib.lines.Line2D at 0x27dd8cf7c40>],
#  'medians': [<matplotlib.lines.Line2D at 0x27dd8d05ac0>],
#  'fliers': [<matplotlib.lines.Line2D at 0x27dd8d05d90>],
#  'means': []}

# %%
#span selector
from matplotlib.widgets import SpanSelector

def onselect(minvalue,maxvalue):
    print(minvalue,maxvalue)
    return (minvalue,maxvalue)

fig,ax=plt.subplots()
ax.plot([1,2,3,4,5,6,7],[10,50,100,23,15,28,45])

span=SpanSelector(ax,
                 onselect,
                 'horizontal',
                 useblit=True,
                 rectprops=dict(alpha:0.3,facecolor:'red')
                 )

plt.show()
# Out:
#   File "C:\Users\SUNATH\AppData\Local\Temp\ipykernel_14040\4116573330.py", line 15
#     rectprops=dict(alpha:0.3,facecolor:'red')
#                         ^
# SyntaxError: invalid syntax

# %%
#broken brah-broken horizontal bar
xranges=[(5,5),(20,5),(20,7)]
yrange=(2,1)
plt.broken_barh(xranges,yrange,facecolors='green')

xranges=[(6,20),(17,5),(50,2)]
yrange=(15,1)
plt.broken_barh(xranges,yrange,facecolors='orange')

xranges=[(5,2),(28,5),(40,2)]
yrange=(30,1)
plt.broken_barh(xranges,yrange,facecolors='red')

plt.xlabel('Sales')
plt.ylabel('days on month')
plt.show()

# %%
#volcano plot(able to see changes in two conditions
from bioinfokit import analys,visuz
visuz.GeneExpression.volcano(dataset=dataset,lfc='log2FC',pv='selling_price',show=True,theme='dark')
dataset
# Out:
# ---------------------------------------------------------------------------
# ModuleNotFoundError                       Traceback (most recent call last)
# ~\AppData\Local\Temp\ipykernel_14040\2287945890.py in <module>
#       1 #volcano plot(able to see changes in two conditions
# ----> 2 from bioinfokit import analys,visuz
#       3 visuz.GeneExpression.volcano(dataset=dataset,lfc='log2FC',pv='selling_price',show=True,theme='dark')
#       4 dataset
#
# ModuleNotFoundError: No module named 'bioinfokit'

# %%
#heatmap
data=np.random.rand(10,10)
plt.imshow(data,cmap='hot',interpolation='nearest')
plt.colorbar()
plt.title('heatmap example')
plt.show()
